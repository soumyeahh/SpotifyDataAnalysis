# %%
import os

# %%
data_folder = os.listdir("/Users/soumya/Desktop/Data stuff/Spotify/SpotifyDataAnalysis")
# Out:
# ['.DS_Store',
#  'merged_data.csv',
#  'Streaming_History_Audio_2022_3.json',
#  'Streaming_History_Audio_2018-2020_0.json',
#  'Streaming_History_Audio_2021-2022_2.json',
#  'Spotify_analysis_notebook.ipynb',
#  'Streaming_History_Audio_2020-2021_1.json',
#  'Streaming_History_Audio_2022-2025_4.json',
#  '.gitattributes',
#  '.ipynb_checkpoints',
#  '.git',
#  'convert_json_to_csv.py']

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading, Exploring and Cleaning the Data

# %%
df = pd.read_csv("/Users/soumya/Desktop/Data stuff/Spotify/SpotifyDataAnalysis/merged_data.csv")

# %%
df
# Out:
#                          ts  \
# 0      2022-01-18T08:34:13Z
# 1      2022-01-18T08:34:13Z
# 2      2022-01-18T08:37:53Z
# 3      2022-01-18T08:37:53Z
# 4      2022-01-18T08:41:33Z
# ...                     ...
# 73759  2025-07-24T04:53:25Z
# 73760  2025-07-26T04:49:12Z
# 73761  2025-07-26T04:54:48Z
# 73762  2025-07-26T04:57:22Z
# 73763  2025-07-27T01:50:56Z
#
#                                                 platform  ms_played  \
# 0      Partner google cast_voice;Google_Home;;5.7.2--...     219919
# 1      Partner google cast_voice;Google_Home;;5.7.2--...     219919
# 2      Partner google cast_voice;Google_Home;;5.7.2--...     218860
# 3      Partner google cast_voice;Google_Home;;5.7.2--...     218860
# 4      Partner google cast_voice;Google_Home;;5.7.2--...     218294
# ...                                                  ...        ...
# 73759                                            android     216364
# 73760                                            android      95742
# ...

# %%
df.shape. #73764 rows and 23 columns
# Out:
# (73764, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73764 entries, 0 to 73763
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ts                                 73764 non-null  object
#  1   platform                           73764 non-null  object
#  2   ms_played                          73764 non-null  int64
#  3   conn_country                       73764 non-null  object
#  4   ip_addr                            73764 non-null  object
#  5   master_metadata_track_name         73629 non-null  object
#  6   master_metadata_album_artist_name  73629 non-null  object
#  7   master_metadata_album_album_name   73629 non-null  object
#  8   spotify_track_uri                  73629 non-null  object
#  9   episode_name                       135 non-null    object
#  10  episode_show_name                  127 non-null    object
# ...

# %%
df['ts'] = pd.to_datetime(df['ts'])

# %%
df['ts'].dtype
# Out:
# datetime64[ns, UTC]

# %%
df['ts']
# Out:
# 0       2022-01-18 08:34:13+00:00
# 1       2022-01-18 08:34:13+00:00
# 2       2022-01-18 08:37:53+00:00
# 3       2022-01-18 08:37:53+00:00
# 4       2022-01-18 08:41:33+00:00
#                    ...
# 73759   2025-07-24 04:53:25+00:00
# 73760   2025-07-26 04:49:12+00:00
# 73761   2025-07-26 04:54:48+00:00
# 73762   2025-07-26 04:57:22+00:00
# 73763   2025-07-27 01:50:56+00:00
# Name: ts, Length: 73764, dtype: datetime64[ns, UTC]

# %%
df['date'] = df['ts'].dt.date

# %%
df['time'] = df['ts'].dt.time

# %%
df.head()
# Out:
#                          ts  \
# 0 2022-01-18 08:34:13+00:00
# 1 2022-01-18 08:34:13+00:00
# 2 2022-01-18 08:37:53+00:00
# 3 2022-01-18 08:37:53+00:00
# 4 2022-01-18 08:41:33+00:00
#
#                                             platform  ms_played conn_country  \
# 0  Partner google cast_voice;Google_Home;;5.7.2--...     219919           US
# 1  Partner google cast_voice;Google_Home;;5.7.2--...     219919           US
# 2  Partner google cast_voice;Google_Home;;5.7.2--...     218860           US
# 3  Partner google cast_voice;Google_Home;;5.7.2--...     218860           US
# 4  Partner google cast_voice;Google_Home;;5.7.2--...     218294           US
#
#                                   ip_addr master_metadata_track_name  \
# 0  2601:600:947f:d080:6512:d65c:459e:4ec4     春光如此卻不得你(<我只喜歡你>影視劇插曲)
# 1  2601:600:947f:d080:6512:d65c:459e:4ec4     春光如此卻不得你(<我只喜歡你>影視劇插曲)
# 2  2601:600:947f:d080:6512:d65c:459e:4ec4          Kabhi Kabhi Aditi
# ...

# %%
df.tail()
# Out:
#                              ts platform  ms_played conn_country  \
# 73759 2025-07-24 04:53:25+00:00  android     216364           CA
# 73760 2025-07-26 04:49:12+00:00  android      95742           CA
# 73761 2025-07-26 04:54:48+00:00  android     257985           CA
# 73762 2025-07-26 04:57:22+00:00  android     152862           CA
# 73763 2025-07-27 01:50:56+00:00  android     103824           CA
#
#              ip_addr                        master_metadata_track_name  \
# 73759  66.234.34.190                             Bade Achhe Lagte Hain
# 73760  66.234.34.190                             Bade Achhe Lagte Hain
# 73761  66.234.34.190  Kya Hua Tera Vada (From "Hum Kisise Kum Naheen")
# 73762  66.234.34.190                  Gulabi Ankhen - From "The Train"
# 73763  66.234.34.190                                           Ammaadi
#
#       master_metadata_album_artist_name  \
# 73759                        Amit Kumar
# 73760                        Amit Kumar
# ...

# %%
df.drop('ts', axis=1, inplace=True)

# %%
df
# Out:
#                                                 platform  ms_played  \
# 0      Partner google cast_voice;Google_Home;;5.7.2--...     219919
# 1      Partner google cast_voice;Google_Home;;5.7.2--...     219919
# 2      Partner google cast_voice;Google_Home;;5.7.2--...     218860
# 3      Partner google cast_voice;Google_Home;;5.7.2--...     218860
# 4      Partner google cast_voice;Google_Home;;5.7.2--...     218294
# ...                                                  ...        ...
# 73759                                            android     216364
# 73760                                            android      95742
# 73761                                            android     257985
# 73762                                            android     152862
# 73763                                            android     103824
#
#       conn_country                                 ip_addr  \
# 0               US  2601:600:947f:d080:6512:d65c:459e:4ec4
# ...

# %%
df.describe() #not many quantitative fields to be able to use describe() effectively
# Out:
#           ms_played  audiobook_title  audiobook_uri  audiobook_chapter_uri  \
# count  7.376400e+04              0.0            0.0                    0.0
# mean   1.566387e+05              NaN            NaN                    NaN
# std    1.062622e+05              NaN            NaN                    NaN
# min    0.000000e+00              NaN            NaN                    NaN
# 25%    3.716100e+04              NaN            NaN                    NaN
# 50%    1.914740e+05              NaN            NaN                    NaN
# 75%    2.299380e+05              NaN            NaN                    NaN
# max    2.306831e+06              NaN            NaN                    NaN
#
#        audiobook_chapter_title  offline_timestamp
# count                      0.0       1.128100e+04
# mean                       NaN       1.329729e+11
# std                        NaN       4.434765e+11
# min                        NaN       1.665796e+09
# ...

# %%
df.isnull()
# Out:
#        platform  ms_played  conn_country  ip_addr  master_metadata_track_name  \
# 0         False      False         False    False                       False
# 1         False      False         False    False                       False
# 2         False      False         False    False                       False
# 3         False      False         False    False                       False
# 4         False      False         False    False                       False
# ...         ...        ...           ...      ...                         ...
# 73759     False      False         False    False                       False
# 73760     False      False         False    False                       False
# 73761     False      False         False    False                       False
# 73762     False      False         False    False                       False
# 73763     False      False         False    False                       False
#
# ...

# %%
df.isnull().sum()
# Out:
# platform                                 0
# ms_played                                0
# conn_country                             0
# ip_addr                                  0
# master_metadata_track_name             135
# master_metadata_album_artist_name      135
# master_metadata_album_album_name       135
# spotify_track_uri                      135
# episode_name                         73629
# episode_show_name                    73637
# spotify_episode_uri                  73629
# audiobook_title                      73764
# audiobook_uri                        73764
# audiobook_chapter_uri                73764
# audiobook_chapter_title              73764
# reason_start                             0
# reason_end                               0
# shuffle                                  0
# skipped                                  0
# offline                                  0
# offline_timestamp                    62483
# incognito_mode                           0
# ...

# %%
df.drop(columns=['episode_name', 'episode_show_name', 'spotify_episode_uri', 'audiobook_title', 'audiobook_uri', 'audiobook_chapter_uri', 'audiobook_chapter_title'], inplace=True)

# %%
df.isnull().sum()
# Out:
# platform                                 0
# ms_played                                0
# conn_country                             0
# ip_addr                                  0
# master_metadata_track_name             135
# master_metadata_album_artist_name      135
# master_metadata_album_album_name       135
# spotify_track_uri                      135
# reason_start                             0
# reason_end                               0
# shuffle                                  0
# skipped                                  0
# offline                                  0
# offline_timestamp                    62483
# incognito_mode                           0
# date                                     0
# time                                     0
# dtype: int64

# %%
df.drop(columns = ['offline_timestamp'], inplace=True)

# %%
df.isnull().sum()
# Out:
# platform                               0
# ms_played                              0
# conn_country                           0
# ip_addr                                0
# master_metadata_track_name           135
# master_metadata_album_artist_name    135
# master_metadata_album_album_name     135
# spotify_track_uri                    135
# reason_start                           0
# reason_end                             0
# shuffle                                0
# skipped                                0
# offline                                0
# incognito_mode                         0
# date                                   0
# time                                   0
# dtype: int64

# %%
##dropping rows with NaN values in a few columns:
df.dropna(subset=['master_metadata_track_name', 'master_metadata_album_artist_name', 'master_metadata_album_album_name', 'spotify_track_uri'])
# Out:
#                                                 platform  ms_played  \
# 0      Partner google cast_voice;Google_Home;;5.7.2--...     219919
# 1      Partner google cast_voice;Google_Home;;5.7.2--...     219919
# 2      Partner google cast_voice;Google_Home;;5.7.2--...     218860
# 3      Partner google cast_voice;Google_Home;;5.7.2--...     218860
# 4      Partner google cast_voice;Google_Home;;5.7.2--...     218294
# ...                                                  ...        ...
# 73759                                            android     216364
# 73760                                            android      95742
# 73761                                            android     257985
# 73762                                            android     152862
# 73763                                            android     103824
#
#       conn_country                                 ip_addr  \
# 0               US  2601:600:947f:d080:6512:d65c:459e:4ec4
# ...

# %%
##Data Cleaning done!!

# %%
df.columns
# Out:
# Index(['platform', 'ms_played', 'conn_country', 'ip_addr',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'incognito_mode', 'date',
#        'time'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73764 entries, 0 to 73763
# Data columns (total 16 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   platform                           73764 non-null  object
#  1   ms_played                          73764 non-null  int64
#  2   conn_country                       73764 non-null  object
#  3   ip_addr                            73764 non-null  object
#  4   master_metadata_track_name         73629 non-null  object
#  5   master_metadata_album_artist_name  73629 non-null  object
#  6   master_metadata_album_album_name   73629 non-null  object
#  7   spotify_track_uri                  73629 non-null  object
#  8   reason_start                       73764 non-null  object
#  9   reason_end                         73764 non-null  object
#  10  shuffle                            73764 non-null  bool
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73764 entries, 0 to 73763
# Data columns (total 16 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   platform                           73764 non-null  object
#  1   ms_played                          73764 non-null  int64
#  2   conn_country                       73764 non-null  object
#  3   ip_addr                            73764 non-null  object
#  4   master_metadata_track_name         73629 non-null  object
#  5   master_metadata_album_artist_name  73629 non-null  object
#  6   master_metadata_album_album_name   73629 non-null  object
#  7   spotify_track_uri                  73629 non-null  object
#  8   reason_start                       73764 non-null  object
#  9   reason_end                         73764 non-null  object
#  10  shuffle                            73764 non-null  bool
# ...

# %%
df['date'][0]
# Out:
# Timestamp('2022-01-18 00:00:00')

# %%
df['time']
# Out:
# 0        08:34:13
# 1        08:34:13
# 2        08:37:53
# 3        08:37:53
# 4        08:41:33
#            ...
# 73759    04:53:25
# 73760    04:49:12
# 73761    04:54:48
# 73762    04:57:22
# 73763    01:50:56
# Name: time, Length: 73764, dtype: object

# %%
df.to_csv("cleaned_spotify_data.csv", index=False)
